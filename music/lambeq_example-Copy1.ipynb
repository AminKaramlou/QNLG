# %%
! pip install lambeq
! pip install pytket-qiskit
! pip install nltk
# !brew install portaudio
# !pip install sounddevice

BATCH_SIZE = 30
LEARNING_RATE = 3e-2
EPOCHS = 4000
SEED = 0
# Out:
# Requirement already satisfied: lambeq in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (0.2.2)
# Requirement already satisfied: jinja2<3.1.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from lambeq) (3.0.3)
# Requirement already satisfied: pytket>=0.19.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from lambeq) (1.1.0)
# Requirement already satisfied: discopy>=0.4.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from lambeq) (0.4.1)
# Requirement already satisfied: spacy>=3.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from lambeq) (3.3.0)
# Requirement already satisfied: tensornetwork in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from lambeq) (0.4.6)
# Requirement already satisfied: torch>=1.10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from lambeq) (1.11.0)
# Requirement already satisfied: transformers in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from lambeq) (4.18.0)
# Requirement already satisfied: pyyaml in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from lambeq) (6.0)
# Requirement already satisfied: numpy>=1.18.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from discopy>=0.4.1->lambeq) (1.22.3)
# Requirement already satisfied: pillow>=6.2.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from discopy>=0.4.1->lambeq) (8.3.2)
# Requirement already satisfied: matplotlib>=3.1.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from discopy>=0.4.1->lambeq) (3.4.3)
# Requirement already satisfied: networkx>=2.4 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from discopy>=0.4.1->lambeq) (2.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jinja2<3.1.0->lambeq) (2.0.1)
# Requirement already satisfied: sympy~=1.6 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pytket>=0.19.2->lambeq) (1.8)
# Requirement already satisfied: scipy<2.0,>=1.7.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pytket>=0.19.2->lambeq) (1.8.0)
# Requirement already satisfied: graphviz~=0.14 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pytket>=0.19.2->lambeq) (0.17)
# Requirement already satisfied: types-pkg-resources in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pytket>=0.19.2->lambeq) (0.1.3)
# Requirement already satisfied: lark-parser~=0.7 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pytket>=0.19.2->lambeq) (0.12.0)
# Requirement already satisfied: typing-extensions~=3.7 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pytket>=0.19.2->lambeq) (3.10.0.2)
# Requirement already satisfied: setuptools in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy>=3.0->lambeq) (56.0.0)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy>=3.0->lambeq) (0.4.1)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy>=3.0->lambeq) (0.7.7)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy>=3.0->lambeq) (1.8.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy>=3.0->lambeq) (2.0.6)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy>=3.0->lambeq) (0.9.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy>=3.0->lambeq) (3.3.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy>=3.0->lambeq) (2.0.7)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy>=3.0->lambeq) (1.0.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy>=3.0->lambeq) (2.4.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy>=3.0->lambeq) (3.0.6)
# Requirement already satisfied: packaging>=20.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy>=3.0->lambeq) (21.0)
# Requirement already satisfied: thinc<8.1.0,>=8.0.14 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy>=3.0->lambeq) (8.0.15)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy>=3.0->lambeq) (4.62.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy>=3.0->lambeq) (2.26.0)
# Requirement already satisfied: pathy>=0.3.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy>=3.0->lambeq) (0.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy>=3.0->lambeq) (3.0.9)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy>=3.0->lambeq) (1.0.7)
# Requirement already satisfied: opt-einsum>=2.3.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from tensornetwork->lambeq) (3.3.0)
# Requirement already satisfied: h5py>=2.9.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from tensornetwork->lambeq) (3.2.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from transformers->lambeq) (0.5.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from transformers->lambeq) (0.12.1)
# Requirement already satisfied: regex!=2019.12.17 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from transformers->lambeq) (2021.10.8)
# Requirement already satisfied: sacremoses in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from transformers->lambeq) (0.0.49)
# Requirement already satisfied: filelock in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from transformers->lambeq) (3.3.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from matplotlib>=3.1.2->discopy>=0.4.1->lambeq) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from matplotlib>=3.1.2->discopy>=0.4.1->lambeq) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from matplotlib>=3.1.2->discopy>=0.4.1->lambeq) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from matplotlib>=3.1.2->discopy>=0.4.1->lambeq) (2.8.2)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pathy>=0.3.5->spacy>=3.0->lambeq) (5.2.1)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0->lambeq) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0->lambeq) (2.0.6)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0->lambeq) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0->lambeq) (2021.5.30)
# Requirement already satisfied: mpmath>=0.19 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from sympy~=1.6->pytket>=0.19.2->lambeq) (1.2.1)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from typer<0.5.0,>=0.3.0->spacy>=3.0->lambeq) (8.0.3)
# Requirement already satisfied: six in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from sacremoses->transformers->lambeq) (1.16.0)
# Requirement already satisfied: joblib in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from sacremoses->transformers->lambeq) (1.0.1)
# WARNING: You are using pip version 22.0.4; however, version 22.2.2 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.9/bin/python3 -m pip install --upgrade pip' command.
# Requirement already satisfied: pytket-qiskit in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (0.24.0)
# Requirement already satisfied: qiskit~=0.36.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pytket-qiskit) (0.36.1)
# Requirement already satisfied: pytket~=1.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pytket-qiskit) (1.1.0)
# Requirement already satisfied: lark-parser~=0.7 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pytket~=1.1->pytket-qiskit) (0.12.0)
# Requirement already satisfied: typing-extensions~=3.7 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pytket~=1.1->pytket-qiskit) (3.10.0.2)
# Requirement already satisfied: networkx~=2.4 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pytket~=1.1->pytket-qiskit) (2.8.4)
# Requirement already satisfied: jinja2~=3.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pytket~=1.1->pytket-qiskit) (3.0.3)
# Requirement already satisfied: types-pkg-resources in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pytket~=1.1->pytket-qiskit) (0.1.3)
# Requirement already satisfied: numpy<2.0,>=1.21.4 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pytket~=1.1->pytket-qiskit) (1.22.3)
# Requirement already satisfied: graphviz~=0.14 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pytket~=1.1->pytket-qiskit) (0.17)
# Requirement already satisfied: sympy~=1.6 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pytket~=1.1->pytket-qiskit) (1.8)
# Requirement already satisfied: scipy<2.0,>=1.7.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pytket~=1.1->pytket-qiskit) (1.8.0)
# Requirement already satisfied: qiskit-aer==0.10.4 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from qiskit~=0.36.0->pytket-qiskit) (0.10.4)
# Requirement already satisfied: qiskit-ignis==0.7.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from qiskit~=0.36.0->pytket-qiskit) (0.7.0)
# Requirement already satisfied: qiskit-terra==0.20.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from qiskit~=0.36.0->pytket-qiskit) (0.20.1)
# Requirement already satisfied: qiskit-ibmq-provider==0.19.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from qiskit~=0.36.0->pytket-qiskit) (0.19.1)
# Requirement already satisfied: python-dateutil>=2.8.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from qiskit-ibmq-provider==0.19.1->qiskit~=0.36.0->pytket-qiskit) (2.8.2)
# Requirement already satisfied: websocket-client>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from qiskit-ibmq-provider==0.19.1->qiskit~=0.36.0->pytket-qiskit) (1.2.1)
# Requirement already satisfied: urllib3>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from qiskit-ibmq-provider==0.19.1->qiskit~=0.36.0->pytket-qiskit) (1.26.7)
# Requirement already satisfied: requests-ntlm>=1.1.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from qiskit-ibmq-provider==0.19.1->qiskit~=0.36.0->pytket-qiskit) (1.1.0)
# Requirement already satisfied: requests>=2.19 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from qiskit-ibmq-provider==0.19.1->qiskit~=0.36.0->pytket-qiskit) (2.26.0)
# Requirement already satisfied: websockets>=10.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from qiskit-ibmq-provider==0.19.1->qiskit~=0.36.0->pytket-qiskit) (10.3)
# Requirement already satisfied: retworkx>=0.8.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from qiskit-ignis==0.7.0->qiskit~=0.36.0->pytket-qiskit) (0.11.0)
# Requirement already satisfied: setuptools>=40.1.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from qiskit-ignis==0.7.0->qiskit~=0.36.0->pytket-qiskit) (56.0.0)
# Requirement already satisfied: tweedledum<2.0,>=1.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from qiskit-terra==0.20.1->qiskit~=0.36.0->pytket-qiskit) (1.1.1)
# Requirement already satisfied: dill>=0.3 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from qiskit-terra==0.20.1->qiskit~=0.36.0->pytket-qiskit) (0.3.4)
# Requirement already satisfied: psutil>=5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from qiskit-terra==0.20.1->qiskit~=0.36.0->pytket-qiskit) (5.8.0)
# Requirement already satisfied: python-constraint>=1.4 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from qiskit-terra==0.20.1->qiskit~=0.36.0->pytket-qiskit) (1.4.0)
# Requirement already satisfied: symengine>=0.9 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from qiskit-terra==0.20.1->qiskit~=0.36.0->pytket-qiskit) (0.9.2)
# Requirement already satisfied: stevedore>=3.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from qiskit-terra==0.20.1->qiskit~=0.36.0->pytket-qiskit) (3.5.0)
# Requirement already satisfied: ply>=3.10 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from qiskit-terra==0.20.1->qiskit~=0.36.0->pytket-qiskit) (3.11)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jinja2~=3.0->pytket~=1.1->pytket-qiskit) (2.0.1)
# Requirement already satisfied: mpmath>=0.19 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from sympy~=1.6->pytket~=1.1->pytket-qiskit) (1.2.1)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.0->qiskit-ibmq-provider==0.19.1->qiskit~=0.36.0->pytket-qiskit) (1.16.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests>=2.19->qiskit-ibmq-provider==0.19.1->qiskit~=0.36.0->pytket-qiskit) (2.0.6)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests>=2.19->qiskit-ibmq-provider==0.19.1->qiskit~=0.36.0->pytket-qiskit) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests>=2.19->qiskit-ibmq-provider==0.19.1->qiskit~=0.36.0->pytket-qiskit) (2021.5.30)
# Requirement already satisfied: ntlm-auth>=1.0.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.19.1->qiskit~=0.36.0->pytket-qiskit) (1.5.0)
# Requirement already satisfied: cryptography>=1.3 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.19.1->qiskit~=0.36.0->pytket-qiskit) (35.0.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from stevedore>=3.0.0->qiskit-terra==0.20.1->qiskit~=0.36.0->pytket-qiskit) (5.8.1)
# Requirement already satisfied: cffi>=1.12 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.19.1->qiskit~=0.36.0->pytket-qiskit) (1.14.6)
# Requirement already satisfied: pycparser in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.19.1->qiskit~=0.36.0->pytket-qiskit) (2.20)
# WARNING: You are using pip version 22.0.4; however, version 22.2.2 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.9/bin/python3 -m pip install --upgrade pip' command.
# Requirement already satisfied: nltk in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (3.6.5)
# Requirement already satisfied: click in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nltk) (8.0.3)
# Requirement already satisfied: tqdm in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nltk) (4.62.3)
# Requirement already satisfied: regex>=2021.8.3 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nltk) (2021.10.8)
# Requirement already satisfied: joblib in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nltk) (1.0.1)
# WARNING: You are using pip version 22.0.4; however, version 22.2.2 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.9/bin/python3 -m pip install --upgrade pip' command.
# Running `brew update --auto-update`...
# ==> Auto-updated Homebrew!
# Updated 1 tap (homebrew/core).
#
# Warning: portaudio 19.7.0 is already installed and up-to-date.
# To reinstall 19.7.0, run:
#   brew reinstall portaudio
# Requirement already satisfied: sounddevice in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (0.4.5)
# Requirement already satisfied: CFFI>=1.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from sounddevice) (1.14.6)
# Requirement already satisfied: pycparser in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from CFFI>=1.0->sounddevice) (2.20)
# WARNING: You are using pip version 22.0.4; however, version 22.2.2 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.9/bin/python3 -m pip install --upgrade pip' command.

# %%
# 1. Create LL(1) parse table for our musical context-free grammar

primary_elements = ['p4', 'p5', 'p7', 'p9', 'p1', 'p2', 'p3', 'p6', 'p8']
secondary_elements = ['s1', 's2', 's3', 's4']
tertiary_elements = ['t1', 't2', 't3']
ground_elements = ['g1', 'g2']

basic_rule = ('M', 'E2')
compo_rule = ('E3', 'S', 'S')
motif_rule = ('E1', 'E1', 'E1', 'E1')

table = {
    'S': {
        'E3': compo_rule,
        'E1': basic_rule,
    },
    'M': {
        'E1': ('E1', 'E1', 'E1', 'E1')
    },
    'E1': {p: (p,) for p in primary_elements},
    'E2': {s: (s,) for s in secondary_elements},
    'E3': {t: (t,) for t in tertiary_elements}
}

table['S'].update({g: (g,) for g in ground_elements})
table['S'].update({p: basic_rule for p in primary_elements})
table['S'].update({t: compo_rule for t in tertiary_elements})
table['M'].update({p: motif_rule for p in primary_elements})

# %%
# 2. Represent the production rules as boxes in discopy

from discopy import Box, Id, Ty, Word

e1 = Ty('e1') # Primary musical element
e2 = Ty('e2') # Seconday musical element
e3 = Ty('e3') # Tertiary musical element
m  = Ty('m')  # Musical motif

# Atomic pregroup types
n = Ty('n')
s = Ty('s')

basic_seq = Box('b_seq', m @ e2, s)
compo_seq = Box('c_seq', e3 @ s @ s, s)
motif = Box('motif', e1 @ e1 @ e1 @ e1, m)

rule_box = {
    basic_rule: basic_seq,
    compo_rule: compo_seq,
    motif_rule: motif
}

rule_box.update({(p,): Word(p, e1) for p in primary_elements})
rule_box.update({(s,): Word(s, e2) for s in secondary_elements})
rule_box.update({(t,): Word(t, e3) for t in tertiary_elements})
rule_box.update({(g,): Word(g, s) for g in ground_elements})

# %%
# 3. Implement an LL(1) parser.

def parse(sentence):
    stack = ['S']
    diagram = Id(s)
    while len(sentence) > 0:
        w = sentence[0]
        if len(stack) == 0:
            raise Exception(f'Unexpected token {w}.')
        top = stack.pop(0)
        if top == w:
            sentence.pop(0)
            continue
        if top not in table:
            raise Exception(f'{top} not recognised.')
        if w not in table[top]:
            raise Exception(f'No rule for [{top}, {w}].')
        rule = table[top][w]
        stack = list(rule) + stack
        diagram <<= rule_box[rule] @ Id(diagram.dom[1:])
    if len(stack) > 0:
        raise Exception('Unexpected end of sentence.')
    return diagram

# %%
# 4. Parse corpus from text

from jax import numpy as np


def read_data(filename):
    labels, sentences = [], []
    with open(filename) as f:
        for line in f:
            labels.append([1, 0] if line[:3] == 'RIT' else [0, 1])
            sentences.append(line[3:].strip())
    return np.array(labels), sentences


train_labels, train_data = read_data('datasets/music_train_data.txt')
dev_labels, dev_data = read_data('datasets/music_dev_data.txt')
test_labels, test_data = read_data('datasets/music_test_data.txt')

train_parses = [parse(sentence.split(' ')) for sentence in train_data]
dev_parses = [parse(sentence.split(' ')) for sentence in dev_data]
test_parses = [parse(sentence.split(' ')) for sentence in test_data]

print(train_data[1])
train_parses[1].draw()
# Out:
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# t3 p8 p1 p8 p1 s4 g1

# %%
# 5. Define functor from our musical context-free grammar to musical pregroups

from discopy import Diagram, Functor

pg_types = {
    e1: n,
    e2: (n @ n @ n @ n).r @ s,
    e3: s @ s.l @ s.l,
    s: s
}

pg_rule_reductions = {
    motif: Id(n @ n @ n @ n),
    basic_seq: Diagram.cups(n @ n @ n @ n, (n @ n @ n @ n).r) @ Id(s),
    compo_seq: Id(s) @ Diagram.cups(s.l @ s.l, s @ s)
}

def pg_reductions(ar):
    if ar in pg_rule_reductions:
        return pg_rule_reductions[ar]
    if isinstance(ar, Word):
        return Word(ar.name, pg_types[ar.cod])
    raise Exception(f"Unexpected box {ar}.")

    
cfg2pg = Functor(ob=pg_types, ar=pg_reductions)

# %%
# 6. Convert parses into discocat diagrams

train_diagrams = [cfg2pg(parse) for parse in train_parses]
dev_diagrams = [cfg2pg(parse) for parse in dev_parses]
test_diagrams = [cfg2pg(parse) for parse in test_parses]

train_diagrams[1].draw()

# %%
# 8. Remove cups from pregroup diagrams
from lambeq import remove_cups


simple_train_diagrams = [remove_cups(parse) for parse in train_diagrams]
simple_dev_diagrams = [remove_cups(parse) for parse in dev_diagrams]
simple_test_diagrams = [remove_cups(parse) for parse in test_diagrams]

simple_train_diagrams[1].draw()

# %%
# 9. Use lambeq to convert rewritten diagrams to circuits

from lambeq import AtomicType, IQPAnsatz



ansatz = IQPAnsatz({AtomicType.NOUN: 1, AtomicType.SENTENCE: 1},
                   n_layers=1, n_single_qubit_params=3)


train_circuits = [ansatz(diagram) for diagram in simple_train_diagrams]
dev_circuits =  [ansatz(diagram) for diagram in simple_dev_diagrams]
test_circuits = [ansatz(diagram) for diagram in simple_test_diagrams]

train_circuits[1].draw(figsize=(10, 20))

# %%
from lambeq import NumpyModel

all_circuits = train_circuits + dev_circuits + test_circuits

model = NumpyModel.from_diagrams(all_circuits, use_jit=True)

# %%
loss = lambda y_hat, y: -np.sum(y * np.log(y_hat)) / len(y)  # binary cross-entropy loss
acc = lambda y_hat, y: np.sum(np.round(y_hat) == y) / len(y) / 2  # half due to double-counting

# %%
from lambeq import QuantumTrainer, SPSAOptimizer

trainer = QuantumTrainer(
    model,
    loss_function=loss,
    epochs=EPOCHS,
    optimizer=SPSAOptimizer,
    optim_hyperparams={'a': 0.2, 'c': 0.06, 'A':0.01*EPOCHS},
    evaluate_functions={'acc': acc},
    evaluate_on_train=True,
    verbose = 'text',
    seed=0
)

# %%
from lambeq import Dataset

train_dataset = Dataset(
            train_circuits,
            train_labels,
            batch_size=BATCH_SIZE)

val_dataset = Dataset(dev_circuits, dev_labels, shuffle=False)

# %%
trainer.fit(train_dataset, val_dataset, logging_step=12)
# Out:
# Epoch 1:     train/loss: 0.7436   valid/loss: 0.6767   train/acc: 0.4600   valid/acc: 0.6800
# Epoch 12:    train/loss: 0.6736   valid/loss: 0.5604   train/acc: 0.6600   valid/acc: 0.7600
# Epoch 24:    train/loss: 0.6468   valid/loss: 0.5297   train/acc: 0.6800   valid/acc: 0.8400
# Epoch 36:    train/loss: 0.6176   valid/loss: 0.5505   train/acc: 0.6600   valid/acc: 0.8000
# Epoch 48:    train/loss: 0.5756   valid/loss: 0.5661   train/acc: 0.7400   valid/acc: 0.7600
# Epoch 60:    train/loss: 0.5656   valid/loss: 0.5093   train/acc: 0.7000   valid/acc: 0.7200
# Epoch 72:    train/loss: 0.5365   valid/loss: 0.4742   train/acc: 0.6800   valid/acc: 0.6800
# Epoch 84:    train/loss: 0.5208   valid/loss: 0.4728   train/acc: 0.7800   valid/acc: 0.8000
# Epoch 96:    train/loss: 0.4854   valid/loss: 0.4966   train/acc: 0.7800   valid/acc: 0.7200
# Epoch 108:   train/loss: 0.4961   valid/loss: 0.4636   train/acc: 0.7400   valid/acc: 0.7600
# Epoch 120:   train/loss: 0.4644   valid/loss: 0.4346   train/acc: 0.7800   valid/acc: 0.8800
# Epoch 132:   train/loss: 0.4448   valid/loss: 0.4345   train/acc: 0.9400   valid/acc: 0.8400
# Epoch 144:   train/loss: 0.4296   valid/loss: 0.4494   train/acc: 0.9600   valid/acc: 0.9600
# Epoch 156:   train/loss: 0.3960   valid/loss: 0.4090   train/acc: 0.9400   valid/acc: 0.8400
# Epoch 168:   train/loss: 0.4031   valid/loss: 0.4366   train/acc: 0.9200   valid/acc: 0.8000
# Epoch 180:   train/loss: 0.4117   valid/loss: 0.4076   train/acc: 0.9600   valid/acc: 0.8000
# Epoch 192:   train/loss: 0.3955   valid/loss: 0.4505   train/acc: 0.9400   valid/acc: 0.8000
# Epoch 204:   train/loss: 0.4154   valid/loss: 0.4051   train/acc: 0.9600   valid/acc: 0.8400
# Epoch 216:   train/loss: 0.3625   valid/loss: 0.4091   train/acc: 0.9800   valid/acc: 0.8000
# Epoch 228:   train/loss: 0.3838   valid/loss: 0.4064   train/acc: 0.9600   valid/acc: 0.8000
# Epoch 240:   train/loss: 0.3463   valid/loss: 0.4006   train/acc: 0.9800   valid/acc: 0.8000
# Epoch 252:   train/loss: 0.3952   valid/loss: 0.4009   train/acc: 0.9400   valid/acc: 0.8400
# Epoch 264:   train/loss: 0.3752   valid/loss: 0.3884   train/acc: 0.9400   valid/acc: 0.8400
# Epoch 276:   train/loss: 0.3596   valid/loss: 0.3883   train/acc: 0.9800   valid/acc: 0.8400
# Epoch 288:   train/loss: 0.3582   valid/loss: 0.3882   train/acc: 0.9400   valid/acc: 0.8400
# Epoch 300:   train/loss: 0.3455   valid/loss: 0.3962   train/acc: 0.9800   valid/acc: 0.8400
# Epoch 312:   train/loss: 0.3510   valid/loss: 0.4136   train/acc: 0.9200   valid/acc: 0.8400
# Epoch 324:   train/loss: 0.3358   valid/loss: 0.4493   train/acc: 0.9600   valid/acc: 0.8000
# Epoch 336:   train/loss: 0.3655   valid/loss: 0.3961   train/acc: 0.9400   valid/acc: 0.8000
# Epoch 348:   train/loss: 0.3658   valid/loss: 0.4075   train/acc: 0.9800   valid/acc: 0.8000
# Epoch 360:   train/loss: 0.3554   valid/loss: 0.4250   train/acc: 0.9600   valid/acc: 0.8400
# Epoch 372:   train/loss: 0.3535   valid/loss: 0.3865   train/acc: 0.9400   valid/acc: 0.8000
# Epoch 384:   train/loss: 0.3519   valid/loss: 0.3707   train/acc: 1.0000   valid/acc: 0.8000
# Epoch 396:   train/loss: 0.3334   valid/loss: 0.3673   train/acc: 0.9800   valid/acc: 0.8400
# Epoch 408:   train/loss: 0.3557   valid/loss: 0.3846   train/acc: 0.9800   valid/acc: 0.8400
# Epoch 420:   train/loss: 0.3193   valid/loss: 0.3925   train/acc: 1.0000   valid/acc: 0.8400
# Epoch 432:   train/loss: 0.3091   valid/loss: 0.3961   train/acc: 1.0000   valid/acc: 0.8400
# Epoch 444:   train/loss: 0.3288   valid/loss: 0.4478   train/acc: 1.0000   valid/acc: 0.8400
# Epoch 456:   train/loss: 0.3097   valid/loss: 0.4420   train/acc: 0.9800   valid/acc: 0.8400
# Epoch 468:   train/loss: 0.3183   valid/loss: 0.4419   train/acc: 0.9800   valid/acc: 0.8400
# Epoch 480:   train/loss: 0.3091   valid/loss: 0.4308   train/acc: 0.9800   valid/acc: 0.8400
# Epoch 492:   train/loss: 0.3378   valid/loss: 0.4460   train/acc: 0.9800   valid/acc: 0.8400
# Epoch 504:   train/loss: 0.3280   valid/loss: 0.4304   train/acc: 0.9800   valid/acc: 0.8400
# Epoch 516:   train/loss: 0.3140   valid/loss: 0.4285   train/acc: 1.0000   valid/acc: 0.8400
# Epoch 528:   train/loss: 0.3239   valid/loss: 0.4692   train/acc: 0.9800   valid/acc: 0.8400
# Epoch 540:   train/loss: 0.3049   valid/loss: 0.4537   train/acc: 0.9800   valid/acc: 0.8400
# Epoch 552:   train/loss: 0.3157   valid/loss: 0.4488   train/acc: 0.9600   valid/acc: 0.8400
# Epoch 564:   train/loss: 0.2991   valid/loss: 0.4272   train/acc: 0.9800   valid/acc: 0.8400
# Epoch 576:   train/loss: 0.3097   valid/loss: 0.4353   train/acc: 0.9800   valid/acc: 0.8400
# Epoch 588:   train/loss: 0.3183   valid/loss: 0.4504   train/acc: 1.0000   valid/acc: 0.8400
# Epoch 600:   train/loss: 0.2997   valid/loss: 0.4598   train/acc: 1.0000   valid/acc: 0.8400
# Epoch 612:   train/loss: 0.3025   valid/loss: 0.4500   train/acc: 1.0000   valid/acc: 0.8400
# Epoch 624:   train/loss: 0.2915   valid/loss: 0.4491   train/acc: 1.0000   valid/acc: 0.8000
# Epoch 636:   train/loss: 0.3047   valid/loss: 0.4549   train/acc: 1.0000   valid/acc: 0.8400
# Epoch 648:   train/loss: 0.3138   valid/loss: 0.4473   train/acc: 0.9800   valid/acc: 0.8400
# Epoch 660:   train/loss: 0.2938   valid/loss: 0.4262   train/acc: 1.0000   valid/acc: 0.8400
# Epoch 672:   train/loss: 0.2865   valid/loss: 0.4399   train/acc: 1.0000   valid/acc: 0.8400
# Epoch 684:   train/loss: 0.3108   valid/loss: 0.4396   train/acc: 1.0000   valid/acc: 0.8400
# Epoch 696:   train/loss: 0.2943   valid/loss: 0.4507   train/acc: 1.0000   valid/acc: 0.8400
# Epoch 708:   train/loss: 0.2970   valid/loss: 0.4691   train/acc: 1.0000   valid/acc: 0.8000
# Epoch 720:   train/loss: 0.2957   valid/loss: 0.4852   train/acc: 1.0000   valid/acc: 0.8400
# Epoch 732:   train/loss: 0.2919   valid/loss: 0.4783   train/acc: 1.0000   valid/acc: 0.8000
# Epoch 744:   train/loss: 0.2866   valid/loss: 0.4890   train/acc: 1.0000   valid/acc: 0.8000
# Epoch 756:   train/loss: 0.2769   valid/loss: 0.4840   train/acc: 1.0000   valid/acc: 0.8000
# Epoch 768:   train/loss: 0.3076   valid/loss: 0.4745   train/acc: 1.0000   valid/acc: 0.8400
# Epoch 780:   train/loss: 0.2746   valid/loss: 0.4946   train/acc: 1.0000   valid/acc: 0.8000
# Epoch 792:   train/loss: 0.2986   valid/loss: 0.4864   train/acc: 1.0000   valid/acc: 0.8000
# Epoch 804:   train/loss: 0.2810   valid/loss: 0.4846   train/acc: 1.0000   valid/acc: 0.8000
# Epoch 816:   train/loss: 0.2677   valid/loss: 0.5021   train/acc: 1.0000   valid/acc: 0.8000
# Epoch 828:   train/loss: 0.2947   valid/loss: 0.4719   train/acc: 0.9800   valid/acc: 0.8000
# Epoch 840:   train/loss: 0.2721   valid/loss: 0.4746   train/acc: 0.9800   valid/acc: 0.8000
# Epoch 852:   train/loss: 0.2897   valid/loss: 0.4794   train/acc: 1.0000   valid/acc: 0.8000
# Epoch 864:   train/loss: 0.2969   valid/loss: 0.4868   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 876:   train/loss: 0.2701   valid/loss: 0.4880   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 888:   train/loss: 0.2891   valid/loss: 0.4967   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 900:   train/loss: 0.2939   valid/loss: 0.4952   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 912:   train/loss: 0.2803   valid/loss: 0.5148   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 924:   train/loss: 0.2845   valid/loss: 0.5116   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 936:   train/loss: 0.2727   valid/loss: 0.5064   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 948:   train/loss: 0.2899   valid/loss: 0.5101   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 960:   train/loss: 0.2996   valid/loss: 0.5076   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 972:   train/loss: 0.2977   valid/loss: 0.5408   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 984:   train/loss: 0.2677   valid/loss: 0.5692   train/acc: 1.0000   valid/acc: 0.7200
# Epoch 996:   train/loss: 0.2759   valid/loss: 0.5869   train/acc: 1.0000   valid/acc: 0.7200
# Epoch 1008:  train/loss: 0.2737   valid/loss: 0.6031   train/acc: 1.0000   valid/acc: 0.7200
# Epoch 1020:  train/loss: 0.2788   valid/loss: 0.5903   train/acc: 1.0000   valid/acc: 0.7200
# Epoch 1032:  train/loss: 0.2928   valid/loss: 0.6118   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 1044:  train/loss: 0.2880   valid/loss: 0.6302   train/acc: 1.0000   valid/acc: 0.7200
# Epoch 1056:  train/loss: 0.2690   valid/loss: 0.6169   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 1068:  train/loss: 0.2534   valid/loss: 0.6577   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 1080:  train/loss: 0.2895   valid/loss: 0.6652   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 1092:  train/loss: 0.2703   valid/loss: 0.6115   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 1104:  train/loss: 0.2813   valid/loss: 0.6227   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 1116:  train/loss: 0.2871   valid/loss: 0.5981   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 1128:  train/loss: 0.2504   valid/loss: 0.6122   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 1140:  train/loss: 0.2802   valid/loss: 0.6156   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 1152:  train/loss: 0.2705   valid/loss: 0.6423   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 1164:  train/loss: 0.2674   valid/loss: 0.6082   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 1176:  train/loss: 0.2506   valid/loss: 0.6079   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 1188:  train/loss: 0.2701   valid/loss: 0.5621   train/acc: 1.0000   valid/acc: 0.7200
# Epoch 1200:  train/loss: 0.2811   valid/loss: 0.5577   train/acc: 1.0000   valid/acc: 0.7200
# Epoch 1212:  train/loss: 0.2687   valid/loss: 0.5463   train/acc: 1.0000   valid/acc: 0.7200
# Epoch 1224:  train/loss: 0.2922   valid/loss: 0.5446   train/acc: 1.0000   valid/acc: 0.7200
# Epoch 1236:  train/loss: 0.2952   valid/loss: 0.5428   train/acc: 1.0000   valid/acc: 0.7200
# Epoch 1248:  train/loss: 0.2849   valid/loss: 0.5393   train/acc: 1.0000   valid/acc: 0.7200
# Epoch 1260:  train/loss: 0.2638   valid/loss: 0.5222   train/acc: 1.0000   valid/acc: 0.7200
# Epoch 1272:  train/loss: 0.2513   valid/loss: 0.5275   train/acc: 1.0000   valid/acc: 0.7200
# Epoch 1284:  train/loss: 0.2505   valid/loss: 0.5262   train/acc: 1.0000   valid/acc: 0.7200
# Epoch 1296:  train/loss: 0.2594   valid/loss: 0.5264   train/acc: 1.0000   valid/acc: 0.7200
# Epoch 1308:  train/loss: 0.2876   valid/loss: 0.5283   train/acc: 1.0000   valid/acc: 0.7200
# Epoch 1320:  train/loss: 0.2419   valid/loss: 0.5066   train/acc: 1.0000   valid/acc: 0.7200
# Epoch 1332:  train/loss: 0.2566   valid/loss: 0.5068   train/acc: 1.0000   valid/acc: 0.7200
# Epoch 1344:  train/loss: 0.2585   valid/loss: 0.5131   train/acc: 1.0000   valid/acc: 0.7200
# Epoch 1356:  train/loss: 0.2573   valid/loss: 0.5078   train/acc: 1.0000   valid/acc: 0.7200
# Epoch 1368:  train/loss: 0.2755   valid/loss: 0.4921   train/acc: 1.0000   valid/acc: 0.7200
# Epoch 1380:  train/loss: 0.2519   valid/loss: 0.5030   train/acc: 1.0000   valid/acc: 0.7200
# Epoch 1392:  train/loss: 0.2664   valid/loss: 0.5063   train/acc: 1.0000   valid/acc: 0.7200
# Epoch 1404:  train/loss: 0.2380   valid/loss: 0.5071   train/acc: 1.0000   valid/acc: 0.7200
# Epoch 1416:  train/loss: 0.2458   valid/loss: 0.5059   train/acc: 1.0000   valid/acc: 0.7200
# Epoch 1428:  train/loss: 0.2585   valid/loss: 0.5098   train/acc: 1.0000   valid/acc: 0.7200
# Epoch 1440:  train/loss: 0.2612   valid/loss: 0.5106   train/acc: 1.0000   valid/acc: 0.7200
# Epoch 1452:  train/loss: 0.2603   valid/loss: 0.5063   train/acc: 1.0000   valid/acc: 0.7200
# Epoch 1464:  train/loss: 0.2643   valid/loss: 0.4834   train/acc: 1.0000   valid/acc: 0.7200
# Epoch 1476:  train/loss: 0.2542   valid/loss: 0.4843   train/acc: 1.0000   valid/acc: 0.7200
# Epoch 1488:  train/loss: 0.2581   valid/loss: 0.4845   train/acc: 1.0000   valid/acc: 0.7200
# Epoch 1500:  train/loss: 0.2609   valid/loss: 0.4771   train/acc: 1.0000   valid/acc: 0.7200
# Epoch 1512:  train/loss: 0.2403   valid/loss: 0.4844   train/acc: 1.0000   valid/acc: 0.7200
# Epoch 1524:  train/loss: 0.2488   valid/loss: 0.4854   train/acc: 1.0000   valid/acc: 0.7200
# Epoch 1536:  train/loss: 0.2582   valid/loss: 0.4914   train/acc: 0.9800   valid/acc: 0.7200
# Epoch 1548:  train/loss: 0.2536   valid/loss: 0.4955   train/acc: 1.0000   valid/acc: 0.7200
# Epoch 1560:  train/loss: 0.2384   valid/loss: 0.4923   train/acc: 1.0000   valid/acc: 0.7200
# Epoch 1572:  train/loss: 0.2605   valid/loss: 0.4784   train/acc: 1.0000   valid/acc: 0.7200
# Epoch 1584:  train/loss: 0.2596   valid/loss: 0.4699   train/acc: 1.0000   valid/acc: 0.7200
# Epoch 1596:  train/loss: 0.2629   valid/loss: 0.4698   train/acc: 1.0000   valid/acc: 0.7200
# Epoch 1608:  train/loss: 0.2585   valid/loss: 0.4649   train/acc: 1.0000   valid/acc: 0.7200
# Epoch 1620:  train/loss: 0.2800   valid/loss: 0.4642   train/acc: 0.9800   valid/acc: 0.7200
# Epoch 1632:  train/loss: 0.2610   valid/loss: 0.4558   train/acc: 1.0000   valid/acc: 0.7200
# Epoch 1644:  train/loss: 0.2429   valid/loss: 0.4481   train/acc: 1.0000   valid/acc: 0.7200
# Epoch 1656:  train/loss: 0.2578   valid/loss: 0.4429   train/acc: 1.0000   valid/acc: 0.7200
# Epoch 1668:  train/loss: 0.2394   valid/loss: 0.4459   train/acc: 1.0000   valid/acc: 0.7200
# Epoch 1680:  train/loss: 0.2662   valid/loss: 0.4536   train/acc: 1.0000   valid/acc: 0.7200
# Epoch 1692:  train/loss: 0.2764   valid/loss: 0.4490   train/acc: 1.0000   valid/acc: 0.7200
# Epoch 1704:  train/loss: 0.2402   valid/loss: 0.4609   train/acc: 0.9800   valid/acc: 0.7200
# Epoch 1716:  train/loss: 0.2578   valid/loss: 0.4635   train/acc: 1.0000   valid/acc: 0.7200
# Epoch 1728:  train/loss: 0.2283   valid/loss: 0.4605   train/acc: 1.0000   valid/acc: 0.7200
# Epoch 1740:  train/loss: 0.2535   valid/loss: 0.4614   train/acc: 1.0000   valid/acc: 0.7200
# Epoch 1752:  train/loss: 0.2546   valid/loss: 0.4536   train/acc: 1.0000   valid/acc: 0.7200
# Epoch 1764:  train/loss: 0.2654   valid/loss: 0.4425   train/acc: 0.9800   valid/acc: 0.7200
# Epoch 1776:  train/loss: 0.2436   valid/loss: 0.4409   train/acc: 1.0000   valid/acc: 0.7200
# Epoch 1788:  train/loss: 0.2711   valid/loss: 0.4341   train/acc: 1.0000   valid/acc: 0.7200
# Epoch 1800:  train/loss: 0.2697   valid/loss: 0.4315   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 1812:  train/loss: 0.2573   valid/loss: 0.4280   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 1824:  train/loss: 0.2478   valid/loss: 0.4273   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 1836:  train/loss: 0.2368   valid/loss: 0.4214   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 1848:  train/loss: 0.2453   valid/loss: 0.4274   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 1860:  train/loss: 0.2204   valid/loss: 0.4269   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 1872:  train/loss: 0.2584   valid/loss: 0.4218   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 1884:  train/loss: 0.2241   valid/loss: 0.4193   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 1896:  train/loss: 0.2444   valid/loss: 0.4138   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 1908:  train/loss: 0.2582   valid/loss: 0.4160   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 1920:  train/loss: 0.2398   valid/loss: 0.4147   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 1932:  train/loss: 0.2483   valid/loss: 0.4162   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 1944:  train/loss: 0.2335   valid/loss: 0.4185   train/acc: 0.9600   valid/acc: 0.7600
# Epoch 1956:  train/loss: 0.2458   valid/loss: 0.4178   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 1968:  train/loss: 0.2367   valid/loss: 0.4157   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 1980:  train/loss: 0.2315   valid/loss: 0.4171   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 1992:  train/loss: 0.2328   valid/loss: 0.4128   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 2004:  train/loss: 0.2321   valid/loss: 0.4088   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 2016:  train/loss: 0.2155   valid/loss: 0.4062   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 2028:  train/loss: 0.2509   valid/loss: 0.3998   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 2040:  train/loss: 0.2291   valid/loss: 0.3977   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 2052:  train/loss: 0.2562   valid/loss: 0.3920   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 2064:  train/loss: 0.2322   valid/loss: 0.3937   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 2076:  train/loss: 0.2412   valid/loss: 0.3939   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 2088:  train/loss: 0.2340   valid/loss: 0.3966   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 2100:  train/loss: 0.2391   valid/loss: 0.3977   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 2112:  train/loss: 0.2420   valid/loss: 0.3950   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 2124:  train/loss: 0.2340   valid/loss: 0.3948   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 2136:  train/loss: 0.2444   valid/loss: 0.3923   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 2148:  train/loss: 0.2300   valid/loss: 0.3890   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 2160:  train/loss: 0.2356   valid/loss: 0.3914   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 2172:  train/loss: 0.2207   valid/loss: 0.3921   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 2184:  train/loss: 0.2316   valid/loss: 0.3948   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 2196:  train/loss: 0.2308   valid/loss: 0.3911   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 2208:  train/loss: 0.2378   valid/loss: 0.3884   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 2220:  train/loss: 0.2352   valid/loss: 0.3898   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 2232:  train/loss: 0.2316   valid/loss: 0.3889   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 2244:  train/loss: 0.2255   valid/loss: 0.3908   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 2256:  train/loss: 0.2335   valid/loss: 0.3910   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 2268:  train/loss: 0.2306   valid/loss: 0.3868   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 2280:  train/loss: 0.2328   valid/loss: 0.3884   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 2292:  train/loss: 0.2354   valid/loss: 0.3910   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 2304:  train/loss: 0.2218   valid/loss: 0.3884   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 2316:  train/loss: 0.2237   valid/loss: 0.3861   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 2328:  train/loss: 0.2372   valid/loss: 0.3849   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 2340:  train/loss: 0.2147   valid/loss: 0.3839   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 2352:  train/loss: 0.2304   valid/loss: 0.3792   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 2364:  train/loss: 0.2288   valid/loss: 0.3799   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 2376:  train/loss: 0.2225   valid/loss: 0.3800   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 2388:  train/loss: 0.2362   valid/loss: 0.3828   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 2400:  train/loss: 0.2152   valid/loss: 0.3818   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 2412:  train/loss: 0.2197   valid/loss: 0.3791   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 2424:  train/loss: 0.2143   valid/loss: 0.3720   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 2436:  train/loss: 0.2189   valid/loss: 0.3670   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 2448:  train/loss: 0.2289   valid/loss: 0.3627   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 2460:  train/loss: 0.2400   valid/loss: 0.3667   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 2472:  train/loss: 0.2108   valid/loss: 0.3699   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 2484:  train/loss: 0.2325   valid/loss: 0.3684   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 2496:  train/loss: 0.2049   valid/loss: 0.3670   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 2508:  train/loss: 0.2384   valid/loss: 0.3707   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 2520:  train/loss: 0.2089   valid/loss: 0.3724   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 2532:  train/loss: 0.2304   valid/loss: 0.3706   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 2544:  train/loss: 0.2108   valid/loss: 0.3690   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 2556:  train/loss: 0.2166   valid/loss: 0.3682   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 2568:  train/loss: 0.2146   valid/loss: 0.3640   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 2580:  train/loss: 0.2247   valid/loss: 0.3624   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 2592:  train/loss: 0.2383   valid/loss: 0.3597   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 2604:  train/loss: 0.2138   valid/loss: 0.3596   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 2616:  train/loss: 0.2176   valid/loss: 0.3609   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 2628:  train/loss: 0.2188   valid/loss: 0.3629   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 2640:  train/loss: 0.2301   valid/loss: 0.3604   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 2652:  train/loss: 0.2277   valid/loss: 0.3569   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 2664:  train/loss: 0.2121   valid/loss: 0.3579   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 2676:  train/loss: 0.2219   valid/loss: 0.3589   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 2688:  train/loss: 0.1973   valid/loss: 0.3637   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 2700:  train/loss: 0.2231   valid/loss: 0.3642   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 2712:  train/loss: 0.2155   valid/loss: 0.3647   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 2724:  train/loss: 0.2115   valid/loss: 0.3625   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 2736:  train/loss: 0.1911   valid/loss: 0.3601   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 2748:  train/loss: 0.2169   valid/loss: 0.3587   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 2760:  train/loss: 0.2250   valid/loss: 0.3585   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 2772:  train/loss: 0.2062   valid/loss: 0.3607   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 2784:  train/loss: 0.1984   valid/loss: 0.3604   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 2796:  train/loss: 0.2089   valid/loss: 0.3558   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 2808:  train/loss: 0.1993   valid/loss: 0.3577   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 2820:  train/loss: 0.2185   valid/loss: 0.3513   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 2832:  train/loss: 0.2244   valid/loss: 0.3492   train/acc: 0.9600   valid/acc: 0.7600
# Epoch 2844:  train/loss: 0.2100   valid/loss: 0.3510   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 2856:  train/loss: 0.2125   valid/loss: 0.3554   train/acc: 0.9600   valid/acc: 0.7600
# Epoch 2868:  train/loss: 0.2267   valid/loss: 0.3554   train/acc: 0.9400   valid/acc: 0.7600
# Epoch 2880:  train/loss: 0.2110   valid/loss: 0.3545   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 2892:  train/loss: 0.2274   valid/loss: 0.3579   train/acc: 0.9600   valid/acc: 0.7600
# Epoch 2904:  train/loss: 0.2087   valid/loss: 0.3590   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 2916:  train/loss: 0.2214   valid/loss: 0.3522   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 2928:  train/loss: 0.2083   valid/loss: 0.3486   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 2940:  train/loss: 0.2138   valid/loss: 0.3460   train/acc: 0.9600   valid/acc: 0.7600
# Epoch 2952:  train/loss: 0.2241   valid/loss: 0.3459   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 2964:  train/loss: 0.2010   valid/loss: 0.3481   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 2976:  train/loss: 0.2106   valid/loss: 0.3436   train/acc: 0.9400   valid/acc: 0.7600
# Epoch 2988:  train/loss: 0.2137   valid/loss: 0.3430   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3000:  train/loss: 0.2046   valid/loss: 0.3445   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3012:  train/loss: 0.2184   valid/loss: 0.3447   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3024:  train/loss: 0.2165   valid/loss: 0.3425   train/acc: 0.9600   valid/acc: 0.7600
# Epoch 3036:  train/loss: 0.2031   valid/loss: 0.3421   train/acc: 0.9400   valid/acc: 0.7600
# Epoch 3048:  train/loss: 0.2369   valid/loss: 0.3413   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3060:  train/loss: 0.2319   valid/loss: 0.3437   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3072:  train/loss: 0.2208   valid/loss: 0.3439   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3084:  train/loss: 0.2171   valid/loss: 0.3430   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3096:  train/loss: 0.2236   valid/loss: 0.3416   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3108:  train/loss: 0.2061   valid/loss: 0.3409   train/acc: 0.9600   valid/acc: 0.7600
# Epoch 3120:  train/loss: 0.1888   valid/loss: 0.3419   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3132:  train/loss: 0.2031   valid/loss: 0.3442   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3144:  train/loss: 0.1990   valid/loss: 0.3417   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3156:  train/loss: 0.2018   valid/loss: 0.3403   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3168:  train/loss: 0.2151   valid/loss: 0.3414   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3180:  train/loss: 0.1938   valid/loss: 0.3400   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3192:  train/loss: 0.2017   valid/loss: 0.3411   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3204:  train/loss: 0.2108   valid/loss: 0.3400   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3216:  train/loss: 0.2074   valid/loss: 0.3383   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 3228:  train/loss: 0.2324   valid/loss: 0.3391   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3240:  train/loss: 0.2051   valid/loss: 0.3370   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3252:  train/loss: 0.2340   valid/loss: 0.3375   train/acc: 0.9600   valid/acc: 0.7600
# Epoch 3264:  train/loss: 0.1994   valid/loss: 0.3383   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3276:  train/loss: 0.2272   valid/loss: 0.3394   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3288:  train/loss: 0.2133   valid/loss: 0.3373   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3300:  train/loss: 0.2219   valid/loss: 0.3421   train/acc: 1.0000   valid/acc: 0.7600
# Epoch 3312:  train/loss: 0.2075   valid/loss: 0.3429   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3324:  train/loss: 0.2210   valid/loss: 0.3421   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3336:  train/loss: 0.2259   valid/loss: 0.3432   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3348:  train/loss: 0.2166   valid/loss: 0.3375   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3360:  train/loss: 0.2282   valid/loss: 0.3379   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3372:  train/loss: 0.2105   valid/loss: 0.3407   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3384:  train/loss: 0.1925   valid/loss: 0.3420   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3396:  train/loss: 0.2237   valid/loss: 0.3444   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3408:  train/loss: 0.1994   valid/loss: 0.3436   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3420:  train/loss: 0.2052   valid/loss: 0.3417   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3432:  train/loss: 0.1992   valid/loss: 0.3419   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3444:  train/loss: 0.2123   valid/loss: 0.3365   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3456:  train/loss: 0.2227   valid/loss: 0.3351   train/acc: 0.9600   valid/acc: 0.7600
# Epoch 3468:  train/loss: 0.2052   valid/loss: 0.3335   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3480:  train/loss: 0.2231   valid/loss: 0.3336   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3492:  train/loss: 0.2056   valid/loss: 0.3334   train/acc: 0.9600   valid/acc: 0.7600
# Epoch 3504:  train/loss: 0.1930   valid/loss: 0.3360   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3516:  train/loss: 0.2010   valid/loss: 0.3393   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3528:  train/loss: 0.2249   valid/loss: 0.3423   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3540:  train/loss: 0.2138   valid/loss: 0.3392   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3552:  train/loss: 0.2189   valid/loss: 0.3357   train/acc: 0.9600   valid/acc: 0.7600
# Epoch 3564:  train/loss: 0.2387   valid/loss: 0.3337   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3576:  train/loss: 0.2276   valid/loss: 0.3344   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3588:  train/loss: 0.2017   valid/loss: 0.3362   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3600:  train/loss: 0.2067   valid/loss: 0.3373   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3612:  train/loss: 0.2269   valid/loss: 0.3339   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3624:  train/loss: 0.2307   valid/loss: 0.3318   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3636:  train/loss: 0.2199   valid/loss: 0.3312   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3648:  train/loss: 0.2039   valid/loss: 0.3310   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3660:  train/loss: 0.2017   valid/loss: 0.3299   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3672:  train/loss: 0.2291   valid/loss: 0.3316   train/acc: 0.9600   valid/acc: 0.7600
# Epoch 3684:  train/loss: 0.2060   valid/loss: 0.3332   train/acc: 0.9600   valid/acc: 0.7600
# Epoch 3696:  train/loss: 0.1975   valid/loss: 0.3331   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3708:  train/loss: 0.1906   valid/loss: 0.3343   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3720:  train/loss: 0.2175   valid/loss: 0.3341   train/acc: 0.9600   valid/acc: 0.7600
# Epoch 3732:  train/loss: 0.2119   valid/loss: 0.3340   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3744:  train/loss: 0.2140   valid/loss: 0.3362   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3756:  train/loss: 0.2185   valid/loss: 0.3423   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3768:  train/loss: 0.2249   valid/loss: 0.3416   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3780:  train/loss: 0.2190   valid/loss: 0.3407   train/acc: 0.9600   valid/acc: 0.7600
# Epoch 3792:  train/loss: 0.2278   valid/loss: 0.3427   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3804:  train/loss: 0.2153   valid/loss: 0.3456   train/acc: 0.9600   valid/acc: 0.7600
# Epoch 3816:  train/loss: 0.2086   valid/loss: 0.3478   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3828:  train/loss: 0.2170   valid/loss: 0.3473   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3840:  train/loss: 0.2244   valid/loss: 0.3465   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3852:  train/loss: 0.2043   valid/loss: 0.3481   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3864:  train/loss: 0.2041   valid/loss: 0.3453   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3876:  train/loss: 0.2106   valid/loss: 0.3431   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3888:  train/loss: 0.2047   valid/loss: 0.3410   train/acc: 0.9600   valid/acc: 0.7600
# Epoch 3900:  train/loss: 0.2185   valid/loss: 0.3409   train/acc: 0.9600   valid/acc: 0.7600
# Epoch 3912:  train/loss: 0.2048   valid/loss: 0.3406   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3924:  train/loss: 0.2137   valid/loss: 0.3423   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3936:  train/loss: 0.1979   valid/loss: 0.3415   train/acc: 0.9600   valid/acc: 0.7600
# Epoch 3948:  train/loss: 0.2093   valid/loss: 0.3412   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3960:  train/loss: 0.2040   valid/loss: 0.3393   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3972:  train/loss: 0.2233   valid/loss: 0.3437   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3984:  train/loss: 0.2154   valid/loss: 0.3460   train/acc: 0.9800   valid/acc: 0.7600
# Epoch 3996:  train/loss: 0.1881   valid/loss: 0.3485   train/acc: 0.9800   valid/acc: 0.7600
#
# Training completed!

# %%
import matplotlib.pyplot as plt

fig, ((ax_tl, ax_tr), (ax_bl, ax_br)) = plt.subplots(2, 2, sharex=True, sharey='row', figsize=(10, 6))
ax_tl.set_title('Training set')
ax_tr.set_title('Development set')
ax_bl.set_xlabel('Iterations')
ax_br.set_xlabel('Iterations')
ax_bl.set_ylabel('Accuracy')
ax_tl.set_ylabel('Loss')

colours = iter(plt.rcParams['axes.prop_cycle'].by_key()['color'])
ax_tl.plot(trainer.train_epoch_costs, color=next(colours))
ax_bl.plot(trainer.train_results['acc'], color=next(colours))
ax_tr.plot(trainer.val_costs, color=next(colours))
ax_br.plot(trainer.val_results['acc'], color=next(colours))

test_acc = acc(model(test_circuits), test_labels)
print('Test accuracy:', test_acc)
# Out:
# Test accuracy: 0.76

# %%
def _measure_quantum_circuit_for_composition(composition):
    diagram = cfg2pg(parse(composition[:]))
    circ = ansatz(diagram)
    return model.get_diagram_output([circ])[0]

# %%
# from itertools import permutations
# valid_compositions = []
# elements = primary_elements + secondary_elements + tertiary_elements + ground_elements

# for i in range(6):
#     for c in permutations(elements, i):
#         try:
#             cfg2pg(parse(list(c)))
#             valid_compositions.append(list(c))
#             print(c)
#         except:
#             continue
# print(valid_compositions)

# %%
import pickle
COMPOSITIONS = pickle.load(open( "valid_compositions.p", "rb" ))
print (COMPOSITIONS)

if [] in COMPOSITIONS: COMPOSITIONS.remove([])
# Out:
# [['g1'], ['g2'], ['t1', 'g1', 'g2'], ['t1', 'g2', 'g1'], ['t2', 'g1', 'g2'], ['t2', 'g2', 'g1'], ['t3', 'g1', 'g2'], ['t3', 'g2', 'g1'], ['p4', 'p5', 'p7', 'p9', 's1'], ['p4', 'p5', 'p7', 'p9', 's2'], ['p4', 'p5', 'p7', 'p9', 's3'], ['p4', 'p5', 'p7', 'p9', 's4'], ['p4', 'p5', 'p7', 'p1', 's1'], ['p4', 'p5', 'p7', 'p1', 's2'], ['p4', 'p5', 'p7', 'p1', 's3'], ['p4', 'p5', 'p7', 'p1', 's4'], ['p4', 'p5', 'p7', 'p2', 's1'], ['p4', 'p5', 'p7', 'p2', 's2'], ['p4', 'p5', 'p7', 'p2', 's3'], ['p4', 'p5', 'p7', 'p2', 's4'], ['p4', 'p5', 'p7', 'p3', 's1'], ['p4', 'p5', 'p7', 'p3', 's2'], ['p4', 'p5', 'p7', 'p3', 's3'], ['p4', 'p5', 'p7', 'p3', 's4'], ['p4', 'p5', 'p7', 'p6', 's1'], ['p4', 'p5', 'p7', 'p6', 's2'], ['p4', 'p5', 'p7', 'p6', 's3'], ['p4', 'p5', 'p7', 'p6', 's4'], ['p4', 'p5', 'p7', 'p8', 's1'], ['p4', 'p5', 'p7', 'p8', 's2'], ['p4', 'p5', 'p7', 'p8', 's3'], ['p4', 'p5', 'p7', 'p8', 's4'], ['p4', 'p5', 'p9', 'p7', 's1'], ['p4', 'p5', 'p9', 'p7', 's2'], ['p4', 'p5', 'p9', 'p7', 's3'], ['p4', 'p5', 'p9', 'p7', 's4'], ['p4', 'p5', 'p9', 'p1', 's1'], ['p4', 'p5', 'p9', 'p1', 's2'], ['p4', 'p5', 'p9', 'p1', 's3'], ['p4', 'p5', 'p9', 'p1', 's4'], ['p4', 'p5', 'p9', 'p2', 's1'], ['p4', 'p5', 'p9', 'p2', 's2'], ['p4', 'p5', 'p9', 'p2', 's3'], ['p4', 'p5', 'p9', 'p2', 's4'], ['p4', 'p5', 'p9', 'p3', 's1'], ['p4', 'p5', 'p9', 'p3', 's2'], ['p4', 'p5', 'p9', 'p3', 's3'], ['p4', 'p5', 'p9', 'p3', 's4'], ['p4', 'p5', 'p9', 'p6', 's1'], ['p4', 'p5', 'p9', 'p6', 's2'], ['p4', 'p5', 'p9', 'p6', 's3'], ['p4', 'p5', 'p9', 'p6', 's4'], ['p4', 'p5', 'p9', 'p8', 's1'], ['p4', 'p5', 'p9', 'p8', 's2'], ['p4', 'p5', 'p9', 'p8', 's3'], ['p4', 'p5', 'p9', 'p8', 's4'], ['p4', 'p5', 'p1', 'p7', 's1'], ['p4', 'p5', 'p1', 'p7', 's2'], ['p4', 'p5', 'p1', 'p7', 's3'], ['p4', 'p5', 'p1', 'p7', 's4'], ['p4', 'p5', 'p1', 'p9', 's1'], ['p4', 'p5', 'p1', 'p9', 's2'], ['p4', 'p5', 'p1', 'p9', 's3'], ['p4', 'p5', 'p1', 'p9', 's4'], ['p4', 'p5', 'p1', 'p2', 's1'], ['p4', 'p5', 'p1', 'p2', 's2'], ['p4', 'p5', 'p1', 'p2', 's3'], ['p4', 'p5', 'p1', 'p2', 's4'], ['p4', 'p5', 'p1', 'p3', 's1'], ['p4', 'p5', 'p1', 'p3', 's2'], ['p4', 'p5', 'p1', 'p3', 's3'], ['p4', 'p5', 'p1', 'p3', 's4'], ['p4', 'p5', 'p1', 'p6', 's1'], ['p4', 'p5', 'p1', 'p6', 's2'], ['p4', 'p5', 'p1', 'p6', 's3'], ['p4', 'p5', 'p1', 'p6', 's4'], ['p4', 'p5', 'p1', 'p8', 's1'], ['p4', 'p5', 'p1', 'p8', 's2'], ['p4', 'p5', 'p1', 'p8', 's3'], ['p4', 'p5', 'p1', 'p8', 's4'], ['p4', 'p5', 'p2', 'p7', 's1'], ['p4', 'p5', 'p2', 'p7', 's2'], ['p4', 'p5', 'p2', 'p7', 's3'], ['p4', 'p5', 'p2', 'p7', 's4'], ['p4', 'p5', 'p2', 'p9', 's1'], ['p4', 'p5', 'p2', 'p9', 's2'], ['p4', 'p5', 'p2', 'p9', 's3'], ['p4', 'p5', 'p2', 'p9', 's4'], ['p4', 'p5', 'p2', 'p1', 's1'], ['p4', 'p5', 'p2', 'p1', 's2'], ['p4', 'p5', 'p2', 'p1', 's3'], ['p4', 'p5', 'p2', 'p1', 's4'], ['p4', 'p5', 'p2', 'p3', 's1'], ['p4', 'p5', 'p2', 'p3', 's2'], ['p4', 'p5', 'p2', 'p3', 's3'], ['p4', 'p5', 'p2', 'p3', 's4'], ['p4', 'p5', 'p2', 'p6', 's1'], ['p4', 'p5', 'p2', 'p6', 's2'], ['p4', 'p5', 'p2', 'p6', 's3'], ['p4', 'p5', 'p2', 'p6', 's4'], ['p4', 'p5', 'p2', 'p8', 's1'], ['p4', 'p5', 'p2', 'p8', 's2'], ['p4', 'p5', 'p2', 'p8', 's3'], ['p4', 'p5', 'p2', 'p8', 's4'], ['p4', 'p5', 'p3', 'p7', 's1'], ['p4', 'p5', 'p3', 'p7', 's2'], ['p4', 'p5', 'p3', 'p7', 's3'], ['p4', 'p5', 'p3', 'p7', 's4'], ['p4', 'p5', 'p3', 'p9', 's1'], ['p4', 'p5', 'p3', 'p9', 's2'], ['p4', 'p5', 'p3', 'p9', 's3'], ['p4', 'p5', 'p3', 'p9', 's4'], ['p4', 'p5', 'p3', 'p1', 's1'], ['p4', 'p5', 'p3', 'p1', 's2'], ['p4', 'p5', 'p3', 'p1', 's3'], ['p4', 'p5', 'p3', 'p1', 's4'], ['p4', 'p5', 'p3', 'p2', 's1'], ['p4', 'p5', 'p3', 'p2', 's2'], ['p4', 'p5', 'p3', 'p2', 's3'], ['p4', 'p5', 'p3', 'p2', 's4'], ['p4', 'p5', 'p3', 'p6', 's1'], ['p4', 'p5', 'p3', 'p6', 's2'], ['p4', 'p5', 'p3', 'p6', 's3'], ['p4', 'p5', 'p3', 'p6', 's4'], ['p4', 'p5', 'p3', 'p8', 's1'], ['p4', 'p5', 'p3', 'p8', 's2'], ['p4', 'p5', 'p3', 'p8', 's3'], ['p4', 'p5', 'p3', 'p8', 's4'], ['p4', 'p5', 'p6', 'p7' ...

# %%
import random
def randomly_generate_composition_with_class(c):
    i = 0
    while i < 100:
        i += 1
        composition = random.choice(COMPOSITIONS)
        prediction = _measure_quantum_circuit_for_composition(composition)
        print(composition)
        print(prediction)
        if c == "Rhytmic" and prediction[0] > 0.98:
            return i, composition
            break
        elif c == "Melodic" and prediction[1] > 0.98:
            return i, composition
            break
    return 100, "Max iterations reached"

# %%
import random
from math import exp

elements = primary_elements + secondary_elements + tertiary_elements + ground_elements
def objective(composition, c):
    try:
        prediction = _measure_quantum_circuit_for_composition(composition)
    except:
        return 0

    if c == "Rhytmic":
        return prediction[0]
    elif c == "Melodic":
        return prediction[1]

def SA_generate_composition(c):
    remaining_compositions = COMPOSITIONS
    checkpoints = []
#### simulated annealing algorithm

    # generate an initial point
    curr = random.choice(remaining_compositions)
    remaining_compositions.remove(curr)
    print("initial_sentence: {}".format(curr))
    # evaluate the initial point
    curr_eval = objective(curr, c)
    print("initial_eval: {}".format(curr_eval))
    if objective(curr, c) > 0.999:
        return 1, curr, [curr]

    temp = 5
    i = 0
    # run the algorithm
    while i < 500:
        checkpoints.append(curr)
        i += 1
        candidate = []
        print("curr: {}".format(curr))
        while candidate not in COMPOSITIONS:
            candidate = curr.copy()
            # Randomly decide on an operation: 0 = DELETE, 1 = Replace, 2 = INSERT
            if len(candidate) == 1:
                op = random.randint(1, 2)
            elif len(candidate) < 6:
                op = random.randint(0, 2)
            else:
                op = random.randint(0, 1)
            if op == 0:
                # Remove random word
                word = random.choice(candidate)
                candidate.remove(word)
            if op == 1:
                new_word = random.choice(elements)
                index = random.randint(0,len(candidate) - 1)
                candidate[index] = new_word
            if op == 2:
                # Add random word at random position
                new_word = random.choice(elements)
                candidate.insert(random.randint(0,len(candidate)),new_word)

        remaining_compositions.remove(candidate)
        print("new candidate: {}".format(candidate))
        candidate_eval = objective(candidate, c)
        print("candidate_eval: {}".format(candidate_eval))
        # check winning criteria
        if candidate_eval > 0.99:
            return i, candidate, checkpoints
        # difference between candidate and current point evaluation
        diff = candidate_eval - curr_eval
        # calculate temperature for current epoch
        t = temp / float(i + 1)
        # calculate metropolis acceptance criterion
        metropolis = exp(diff / t)
        # check if we should keep the new point
        random_float = random.uniform(0,1)
        if diff > 0 or (random.uniform(0, 1) < metropolis):
        # store the new current point
            print("Switch")
            curr, curr_eval = candidate, candidate_eval
        else: 
            print("No switch")
        print("End of iteration: {}".format(i))
    return 500, "Max iterations reached", checkpoints

# %%
import pygame
# setting up pygame
pygame.init()
MUSIC_END = pygame.USEREVENT+1

def start_playlist(playList):
	
	# Loading first audio file into our player
	pygame.mixer.music.load(playList[0])
	
	# Removing the loaded song from our playlist list
	playList.pop(0)

	# Playing our music
	pygame.mixer.music.play()

	# Queueing next song into our player
	pygame.mixer.music.queue(playList[0])
	playList.pop(0)

	# setting up an end event which host an event
	# after the end of every song
	pygame.mixer.music.set_endevent(MUSIC_END)

	# Playing the songs in the background
	running = True
	while running:
		
		# checking if any event has been
		# hosted at time of playing
		for event in pygame.event.get():
			
			# A event will be hosted
			# after the end of every song
			if event.type == MUSIC_END:
				print('Song Finished')
				
				# Checking our playList
				# that if any song exist or
				# it is empty
				if len(playList) > 0:
					
					# if song available then load it in player
					# and remove from the player
					pygame.mixer.music.queue(playList[0])
					playList.pop(0)

			# Checking whether the
			# player is still playing any song
			# if yes it will return true and false otherwise
			if not pygame.mixer.music.get_busy():
				print("Playlist completed")
				
				# When the playlist has
				# completed playing successfully
				# we'll go out of the
				# while-loop by using break
				running = False
				break

# %%
test_composition = ["p5", "p7", "p7", "p9", "s2"]
prediction = _measure_quantum_circuit_for_composition(test_composition)
print(prediction)
# Out:
# [0.9896996  0.01030038]

# %%
import sounddevice as sd
from scipy.io.wavfile import write
from pprint import pprint

checkpoints = SA_generate_composition("Rhytmic")[2]

with open('./checkpoint_sounds/checkpoints.txt', 'wt') as out:
    pprint(checkpoints, stream=out)

#
# Out:
# initial_sentence: ['p5', 'p1', 'p8', 'p3', 's4']
# initial_eval: 0.968716561794281
# curr: ['p5', 'p1', 'p8', 'p3', 's4']
# new candidate: ['p5', 'p1', 'p8', 'p2', 's4']
# candidate_eval: 0.971267819404602
# Switch
# End of iteration: 1
# curr: ['p5', 'p1', 'p8', 'p2', 's4']
# new candidate: ['p3', 'p1', 'p8', 'p2', 's4']
# candidate_eval: 0.4618557095527649
# Switch
# End of iteration: 2
# curr: ['p3', 'p1', 'p8', 'p2', 's4']
# new candidate: ['p3', 'p1', 'p8', 'p9', 's4']
# candidate_eval: 0.4603314995765686
# Switch
# End of iteration: 3
# curr: ['p3', 'p1', 'p8', 'p9', 's4']
# new candidate: ['p4', 'p1', 'p8', 'p9', 's4']
# candidate_eval: 0.9585633873939514
# Switch
# End of iteration: 4
# curr: ['p4', 'p1', 'p8', 'p9', 's4']
# new candidate: ['p6', 'p1', 'p8', 'p9', 's4']
# candidate_eval: 0.012465962208807468
# No switch
# End of iteration: 5
# curr: ['p4', 'p1', 'p8', 'p9', 's4']
# new candidate: ['p4', 'p2', 'p8', 'p9', 's4']
# candidate_eval: 0.9584342241287231
# Switch
# End of iteration: 6
# curr: ['p4', 'p2', 'p8', 'p9', 's4']
# new candidate: ['p4', 'p2', 'p8', 'p9', 's2']
# candidate_eval: 0.9767963290214539
# Switch
# End of iteration: 7
# curr: ['p4', 'p2', 'p8', 'p9', 's2']
# new candidate: ['p5', 'p2', 'p8', 'p9', 's2']
# candidate_eval: 0.9738809466362
# Switch
# End of iteration: 8
# curr: ['p5', 'p2', 'p8', 'p9', 's2']
# new candidate: ['p5', 'p2', 'p8', 'p4', 's2']
# candidate_eval: 0.9741818904876709
# Switch
# End of iteration: 9
# curr: ['p5', 'p2', 'p8', 'p4', 's2']
# new candidate: ['p5', 'p2', 'p1', 'p4', 's2']
# candidate_eval: 0.974705159664154
# Switch
# End of iteration: 10
# curr: ['p5', 'p2', 'p1', 'p4', 's2']
# new candidate: ['p6', 'p2', 'p1', 'p4', 's2']
# candidate_eval: 0.014700244180858135
# No switch
# End of iteration: 11
# curr: ['p5', 'p2', 'p1', 'p4', 's2']
# new candidate: ['p5', 'p2', 'p3', 'p4', 's2']
# candidate_eval: 0.9743921756744385
# Switch
# End of iteration: 12
# curr: ['p5', 'p2', 'p3', 'p4', 's2']
# new candidate: ['p5', 'p2', 'p6', 'p4', 's2']
# candidate_eval: 0.9747177362442017
# Switch
# End of iteration: 13
# curr: ['p5', 'p2', 'p6', 'p4', 's2']
# new candidate: ['p9', 'p2', 'p6', 'p4', 's2']
# candidate_eval: 0.9763979911804199
# Switch
# End of iteration: 14
# curr: ['p9', 'p2', 'p6', 'p4', 's2']
# new candidate: ['p9', 'p2', 'p8', 'p4', 's2']
# candidate_eval: 0.9776652455329895
# Switch
# End of iteration: 15
# curr: ['p9', 'p2', 'p8', 'p4', 's2']
# new candidate: ['p9', 'p2', 'p7', 'p4', 's2']
# candidate_eval: 0.97665935754776
# Switch
# End of iteration: 16
# curr: ['p9', 'p2', 'p7', 'p4', 's2']
# new candidate: ['p9', 'p2', 'p1', 'p4', 's2']
# candidate_eval: 0.9764081835746765
# Switch
# End of iteration: 17
# curr: ['p9', 'p2', 'p1', 'p4', 's2']
# new candidate: ['p9', 'p2', 'p3', 'p4', 's2']
# candidate_eval: 0.9764572978019714
# Switch
# End of iteration: 18
# curr: ['p9', 'p2', 'p3', 'p4', 's2']
# new candidate: ['p9', 'p2', 'p3', 'p1', 's2']
# candidate_eval: 0.9760959148406982
# Switch
# End of iteration: 19
# curr: ['p9', 'p2', 'p3', 'p1', 's2']
# new candidate: ['p9', 'p7', 'p3', 'p1', 's2']
# candidate_eval: 0.9697409868240356
# Switch
# End of iteration: 20
# curr: ['p9', 'p7', 'p3', 'p1', 's2']
# new candidate: ['p9', 'p7', 'p6', 'p1', 's2']
# candidate_eval: 0.9678884148597717
# Switch
# End of iteration: 21
# curr: ['p9', 'p7', 'p6', 'p1', 's2']
# new candidate: ['p9', 'p7', 'p5', 'p1', 's2']
# candidate_eval: 0.9672325849533081
# Switch
# End of iteration: 22
# curr: ['p9', 'p7', 'p5', 'p1', 's2']
# new candidate: ['p9', 'p7', 'p5', 'p1', 's4']
# candidate_eval: 0.9931991696357727

# %%
snippet_files = ["./snippets/{}.mid".format(s) for s in checkpoints[-1]]
print(snippet_files)
start_playlist(snippet_files)

# for i,c in list(enumerate(checkpoints))[::5]:
#     snippet_files = ["./snippets/{}.mid".format(s) for s in c]
#     print(snippet_files)
#     fs = 300000  # Sample rate
#     seconds = 30  # Duration of recording
#     myrecording = sd.rec(int(seconds * fs), samplerate=fs, channels=1)
#     start_playlist(snippet_files)
#     sd.wait()  # Wait until recording is finished
#     write('./checkpoint_sounds/checkpoint_{}.wav'.format(i), fs, myrecording)  # Save as WAV file
# Out:
# ['./snippets/p9.mid', './snippets/p7.mid', './snippets/p5.mid', './snippets/p1.mid', './snippets/s2.mid']
# Song Finished
# Song Finished
# Song Finished
# Song Finished
# Song Finished
# Playlist completed
